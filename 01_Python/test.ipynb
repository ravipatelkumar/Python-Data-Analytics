# %%
# Day 01 - Python Basics

print("Hello Ravi 🚀")
# Out:
# Hello Ravi 🚀

# %%
name = "Ravi"

print(name)
# Out:
# Ravi

# %%
age = 25

print(age)
# Out:
# 25

# %%
print(type(name))
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>
